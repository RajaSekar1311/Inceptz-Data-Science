# %%
# Libraries

import pandas as pd
import numpy as np

# %%
train = pd.read_csv("Train.csv")
test = pd.read_csv("Test.csv")
sample = pd.read_csv("sample_submission.csv")

# %%
train.head()
# Out:
#   POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  \
# 0     Owner                   0     0        2       BHK  1300.236407
# 1    Dealer                   0     0        2       BHK  1275.000000
# 2     Owner                   0     0        2       BHK   933.159722
# 3     Owner                   0     1        2       BHK   929.921143
# 4    Dealer                   1     0        2       BHK   999.009247
#
#    READY_TO_MOVE  RESALE                      ADDRESS  LONGITUDE   LATITUDE  \
# 0              1       1        Ksfc Layout,Bangalore  12.969910  77.597960
# 1              1       1    Vishweshwara Nagar,Mysore  12.274538  76.644605
# 2              1       1             Jigani,Bangalore  12.778033  77.632191
# 3              1       1  Sector-1 Vaishali,Ghaziabad  28.642300  77.344500
# 4              0       1             New Town,Kolkata  22.592200  88.484911
#
#    TARGET(PRICE_IN_LACS) source
# 0                   55.0  train
# 1                   51.0  train
# 2                   43.0  train
# 3                   62.5  train
# 4                   60.5  train

# %%
train["source"] = "train"
test["source"] = "test"

# %%
df = pd.concat([train,test])
df
# Out:
#       POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK     SQUARE_FT  \
# 0         Owner                   0     0        2       BHK   1300.236407
# 1        Dealer                   0     0        2       BHK   1275.000000
# 2         Owner                   0     0        2       BHK    933.159722
# 3         Owner                   0     1        2       BHK    929.921143
# 4        Dealer                   1     0        2       BHK    999.009247
# ...         ...                 ...   ...      ...       ...           ...
# 68715    Dealer                   0     1        2       BHK    856.555505
# 68716    Dealer                   0     1        3       BHK   2304.147465
# 68717    Dealer                   1     1        1       BHK  33362.792750
# 68718    Dealer                   0     0        2       BHK   1173.708920
# 68719    Dealer                   0     0        3       BHK   2439.532944
#
#        READY_TO_MOVE  RESALE                             ADDRESS  LONGITUDE  \
# 0                  1       1               Ksfc Layout,Bangalore  12.969910
# 1                  1       1           Vishweshwara Nagar,Mysore  12.274538
# 2                  1       1                    Jigani,Bangalore  12.778033
# 3                  1       1         Sector-1 Vaishali,Ghaziabad  28.642300
# 4                  0       1                    New Town,Kolkata  22.592200
# ...              ...     ...                                 ...        ...
# 68715              1       1              Thane West,Maharashtra  19.180000
# 68716              1       1            Sector-66A Mohali,Mohali  30.661104
# 68717              0       0                  Balkum,Maharashtra  19.222101
# 68718              1       1                       Hadapsar,Pune  18.496670
# 68719              1       1  Hiranandani Gardens - Powai,Mumbai  19.124896
#
#         LATITUDE  TARGET(PRICE_IN_LACS) source
# 0      77.597960                   55.0  train
# 1      76.644605                   51.0  train
# 2      77.632191                   43.0  train
# 3      77.344500                   62.5  train
# 4      88.484911                   60.5  train
# ...          ...                    ...    ...
# 68715  72.963330                    NaN   test
# 68716  76.746082                    NaN   test
# 68717  72.988231                    NaN   test
# 68718  73.941670                    NaN   test
# 68719  72.893503                    NaN   test
#
# [98171 rows x 13 columns]

# %%
df.rename(columns={"RERA": "AREA"})
# Out:
#       POSTED_BY  UNDER_CONSTRUCTION  AREA  BHK_NO. BHK_OR_RK     SQUARE_FT  \
# 0         Owner                   0     0        2       BHK   1300.236407
# 1        Dealer                   0     0        2       BHK   1275.000000
# 2         Owner                   0     0        2       BHK    933.159722
# 3         Owner                   0     1        2       BHK    929.921143
# 4        Dealer                   1     0        2       BHK    999.009247
# ...         ...                 ...   ...      ...       ...           ...
# 68715    Dealer                   0     1        2       BHK    856.555505
# 68716    Dealer                   0     1        3       BHK   2304.147465
# 68717    Dealer                   1     1        1       BHK  33362.792750
# 68718    Dealer                   0     0        2       BHK   1173.708920
# 68719    Dealer                   0     0        3       BHK   2439.532944
#
#        READY_TO_MOVE  RESALE  LONGITUDE   LATITUDE  TARGET(PRICE_IN_LACS)  \
# 0                  1       1  12.969910  77.597960                   55.0
# 1                  1       1  12.274538  76.644605                   51.0
# 2                  1       1  12.778033  77.632191                   43.0
# 3                  1       1  28.642300  77.344500                   62.5
# 4                  0       1  22.592200  88.484911                   60.5
# ...              ...     ...        ...        ...                    ...
# 68715              1       1  19.180000  72.963330                    NaN
# 68716              1       1  30.661104  76.746082                    NaN
# 68717              0       0  19.222101  72.988231                    NaN
# 68718              1       1  18.496670  73.941670                    NaN
# 68719              1       1  19.124896  72.893503                    NaN
#
#       source
# 0      train
# 1      train
# 2      train
# 3      train
# 4      train
# ...      ...
# 68715   test
# 68716   test
# 68717   test
# 68718   test
# 68719   test
#
# [98171 rows x 12 columns]

# %%
df=df.rename(columns={"RERA": "AREA"})

# %%
df_number_columns=df.select_dtypes(include = np.number).columns

# %%
df_category_columns = df.select_dtypes(exclude = np.number).columns

# %%
data_to_encode = df[df_category_columns].drop(columns = ["source"])
df_category_encoded = pd.get_dummies(data_to_encode)

# %%
df_category_encoded
# Out:
#        POSTED_BY_Builder  POSTED_BY_Dealer  POSTED_BY_Owner  BHK_OR_RK_BHK  \
# 0                      0                 0                1              1
# 1                      0                 1                0              1
# 2                      0                 0                1              1
# 3                      0                 0                1              1
# 4                      0                 1                0              1
# ...                  ...               ...              ...            ...
# 68715                  0                 1                0              1
# 68716                  0                 1                0              1
# 68717                  0                 1                0              1
# 68718                  0                 1                0              1
# 68719                  0                 1                0              1
#
#        BHK_OR_RK_RK
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                 0
# ...             ...
# 68715             0
# 68716             0
# 68717             0
# 68718             0
# 68719             0
#
# [98171 rows x 5 columns]

# %%
df_final = pd.concat([df_category_encoded, df[df_number_columns],df["source"]], axis= 1)

# %%
df_final
# Out:
#        POSTED_BY_Builder  POSTED_BY_Dealer  POSTED_BY_Owner  BHK_OR_RK_BHK  \
# 0                      0                 0                1              1
# 1                      0                 1                0              1
# 2                      0                 0                1              1
# 3                      0                 0                1              1
# 4                      0                 1                0              1
# ...                  ...               ...              ...            ...
# 68715                  0                 1                0              1
# 68716                  0                 1                0              1
# 68717                  0                 1                0              1
# 68718                  0                 1                0              1
# 68719                  0                 1                0              1
#
#        BHK_OR_RK_RK  UNDER_CONSTRUCTION  AREA  BHK_NO.     SQUARE_FT  \
# 0                 0                   0     0        2   1300.236407
# 1                 0                   0     0        2   1275.000000
# 2                 0                   0     0        2    933.159722
# 3                 0                   0     1        2    929.921143
# 4                 0                   1     0        2    999.009247
# ...             ...                 ...   ...      ...           ...
# 68715             0                   0     1        2    856.555505
# 68716             0                   0     1        3   2304.147465
# 68717             0                   1     1        1  33362.792750
# 68718             0                   0     0        2   1173.708920
# 68719             0                   0     0        3   2439.532944
#
#        READY_TO_MOVE  RESALE  LONGITUDE   LATITUDE  TARGET(PRICE_IN_LACS)  \
# 0                  1       1  12.969910  77.597960                   55.0
# 1                  1       1  12.274538  76.644605                   51.0
# 2                  1       1  12.778033  77.632191                   43.0
# 3                  1       1  28.642300  77.344500                   62.5
# 4                  0       1  22.592200  88.484911                   60.5
# ...              ...     ...        ...        ...                    ...
# 68715              1       1  19.180000  72.963330                    NaN
# 68716              1       1  30.661104  76.746082                    NaN
# 68717              0       0  19.222101  72.988231                    NaN
# 68718              1       1  18.496670  73.941670                    NaN
# 68719              1       1  19.124896  72.893503                    NaN
#
#       source
# 0      train
# 1      train
# 2      train
# 3      train
# 4      train
# ...      ...
# 68715   test
# 68716   test
# 68717   test
# 68718   test
# 68719   test
#
# [98171 rows x 15 columns]

# %%
train_preprocessed = df_final[df_final["source"]=="train"]
test_preprocessed = df_final[df_final["source"]=="test"]

# %%
del train_preprocessed["source"]
del test_preprocessed["source"]

# %%
train_preprocessed.to_csv("train_HPPSales_Preprocessed.csv", index = False)
test_preprocessed.to_csv("test_HPPSales_Preprocessed.csv", index = False)
